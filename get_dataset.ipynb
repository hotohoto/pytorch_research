# %% [markdown]
# # Prepare Dataset

# %%
from functools import reduce
import glob
import math
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import os
import os.path
import pprint
import random
import string
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tarfile
import time
import unicodedata
import urllib.request
import zipfile

# %%
def reporthook(count, block_size, total_size):
    global start_time
    if count == 0:
        start_time = time.time()
        return
    if count * block_size >= total_size:
        print('')
        return
    if count % 100 != 0:
        return
    print('.', end='')

def maybe_download(url, destination_path):
    if os.path.exists(destination_path):
        return
    
    dirpath, filename = os.path.split(destination_path)
    os.makedirs(dirpath, exist_ok=True)
    urllib.request.urlretrieve(url, destination_path, reporthook)

def reduce_folder_depth(folder_path):
    parent_path, folder_name = os.path.split(folder_path)
    files = os.listdir(folder_path)
    if len(files) == 1 and files[0] == folder_name:
        tmp_dir_path = os.path.join(folder_path, '.__tmp_dir__')
        os.rename(os.path.join(folder_path, files[0]), tmp_dir_path)
        innerfiles = os.listdir(tmp_dir_path)
        for f in innerfiles:
            os.rename(os.path.join(tmp_dir_path, f), os.path.join(folder_path, f))
        os.rmdir(tmp_dir_path)
        

def maybe_unzip(source_zip_file_path):
    dirpath, filename = os.path.split(source_zip_file_path)
    name, ext = os.path.splitext(filename)
    destination_folder = os.path.join(dirpath, name)

    if os.path.exists(destination_folder):
        return
    if destination_folder and not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    with zipfile.ZipFile(source_zip_file_path) as z:
        zip_ref.extractall(destination_folder)
    reduce_folder_depth(destination_folder)
    return destination_folder
        
def maybe_extract_tar(source_tar_file_path):
    dirpath, filename = os.path.split(source_tar_file_path)
    name, ext = os.path.splitext(filename)
    destination_folder = os.path.join(dirpath, name)

    if os.path.exists(destination_folder):
        return destination_folder
    if destination_folder and not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    with tarfile.open(source_tar_file_path) as t:
        t.extractall(destination_folder)
    reduce_folder_depth(destination_folder)
    return destination_folder

# %%
def bundle_dataset(list):
    files = [
        {
            'name': f,
            'path': os.path.join(data_path, f),
            'size': os.stat(os.path.join(data_path, f)).st_size,
            'handle': None
        }
        for f in list
    ]
    total_size = reduce((lambda x, y: x + y), map((lambda x: x['size']), files))
    return {
        'files': files,
        'total_size': total_size
    }

# %%
DATA_URL = 'http://www.thespermwhale.com/jaseweston/babi/CBTest.tgz'
DATA_SOURCE_PATH = os.path.join('data', 'CBTest.tgz')

maybe_download(DATA_URL, DATA_SOURCE_PATH)
extracted_dir = maybe_extract_tar(DATA_SOURCE_PATH)

data_path = os.path.join(extracted_dir, 'data')
input_files =  os.listdir(data_path)

train_dataset = bundle_dataset([f for f in input_files if '_train' in f])
valid_dataset = bundle_dataset([f for f in input_files if '_valid' in f])
test_dataset = bundle_dataset([f for f in input_files if '_test' in f])

pp = pprint.PrettyPrinter(indent=2)
pp.pprint(train_dataset)
pp.pprint(valid_dataset)
pp.pprint(test_dataset)
# Out:
# { 'files': [ { 'handle': None,
#                'name': 'cbt_train.txt',
#                'path': 'data/CBTest/data/cbt_train.txt',
#                'size': 25742364},
#              { 'handle': None,
#                'name': 'cbtest_CN_train.txt',
#                'path': 'data/CBTest/data/cbtest_CN_train.txt',
#                'size': 295933246},
#              { 'handle': None,
#                'name': 'cbtest_NE_train.txt',
#                'path': 'data/CBTest/data/cbtest_NE_train.txt',
#                'size': 248333387},
#              { 'handle': None,
#                'name': 'cbtest_P_train.txt',
#                'path': 'data/CBTest/data/cbtest_P_train.txt',
#                'size': 836819208},
#              { 'handle': None,
#                'name': 'cbtest_V_train.txt',
#                'path': 'data/CBTest/data/cbtest_V_train.txt',
#                'size': 247098043}],
#   'total_size': 1653926248}
# { 'files': [ { 'handle': None,
#                'name': 'cbt_valid.txt',
#                'path': 'data/CBTest/data/cbt_valid.txt',
#                'size': 1182697},
#              { 'handle': None,
#                'name': 'cbtest_CN_valid_2000ex.txt',
#                'path': 'data/CBTest/data/cbtest_CN_valid_2000ex.txt',
#                'size': 4641257},
#              { 'handle': None,
#                'name': 'cbtest_NE_valid_2000ex.txt',
#                'path': 'data/CBTest/data/cbtest_NE_valid_2000ex.txt',
#                'size': 4328316},
#              { 'handle': None,
#                'name': 'cbtest_P_valid_2000ex.txt',
#                'path': 'data/CBTest/data/cbtest_P_valid_2000ex.txt',
#                'size': 4680981},
#              { 'handle': None,
#                'name': 'cbtest_V_valid_2000ex.txt',
#                'path': 'data/CBTest/data/cbtest_V_valid_2000ex.txt',
#                'size': 4460425}],
#   'total_size': 19293676}
# { 'files': [ { 'handle': None,
#                'name': '.cbt_test.txt.swp',
#                'path': 'data/CBTest/data/.cbt_test.txt.swp',
#                'size': 1024},
#              { 'handle': None,
#                'name': 'cbt_test.txt',
#                'path': 'data/CBTest/data/cbt_test.txt',
#                'size': 1528744},
#              { 'handle': None,
#                'name': 'cbtest_CN_test_2500ex.txt',
#                'path': 'data/CBTest/data/cbtest_CN_test_2500ex.txt',
#                'size': 6018376},
#              { 'handle': None,
#                'name': 'cbtest_NE_test_2500ex.txt',
#                'path': 'data/CBTest/data/cbtest_NE_test_2500ex.txt',
#                'size': 5587722},
#              { 'handle': None,
#                'name': 'cbtest_P_test_2500ex.txt',
#                'path': 'data/CBTest/data/cbtest_P_test_2500ex.txt',
#                'size': 5958048},
#              { 'handle': None,
#                'name': 'cbtest_V_test_2500ex.txt',
#                'path': 'data/CBTest/data/cbtest_V_test_2500ex.txt',
#                'size': 5686625}],
#   'total_size': 24780539}

# %%
DATA_URL = 'http://archives.textfiles.com/stories.tar.gz'
DATA_SOURCE_PATH = os.path.join('data', 'stories.tgz')

maybe_download(DATA_URL, DATA_SOURCE_PATH)
extracted_dir = maybe_extract_tar(DATA_SOURCE_PATH)

data_path = os.path.join(extracted_dir)
input_files =  os.listdir(data_path)

train_dataset = bundle_dataset([f for f in input_files if os.path.isfile(os.path.join(data_path, f))])

pp = pprint.PrettyPrinter(indent=2)
pp.pprint(train_dataset)
pp.pprint(valid_dataset)
pp.pprint(test_dataset)
# Out:
# { 'files': [ { 'handle': None,
#                'name': '100west.txt',
#                'path': 'data/stories/100west.txt',
#                'size': 20839},
#              { 'handle': None,
#                'name': '13chil.txt',
#                'path': 'data/stories/13chil.txt',
#                'size': 8457},
#              { 'handle': None,
#                'name': '14.lws',
#                'path': 'data/stories/14.lws',
#                'size': 5261},
#              { 'handle': None,
#                'name': '16.lws',
#                'path': 'data/stories/16.lws',
#                'size': 15294},
#              { 'handle': None,
#                'name': '17.lws',
#                'path': 'data/stories/17.lws',
#                'size': 10853},
#              { 'handle': None,
#                'name': '18.lws',
#                'path': 'data/stories/18.lws',
#                'size': 26624},
#              { 'handle': None,
#                'name': '19.lws',
#                'path': 'data/stories/19.lws',
#                'size': 17902},
#              { 'handle': None,
#                'name': '20.lws',
#                'path': 'data/stories/20.lws',
#                'size': 13588},
#              { 'handle': None,
#                'name': '3gables.txt',
#                'path': 'data/stories/3gables.txt',
#                'size': 33985},
#              { 'handle': None,
#                'name': '3lpigs.txt',
#                'path': 'data/stories/3lpigs.txt',
#                'size': 5403},
#              { 'handle': None,
#                'name': '3sonnets.vrs',
#                'path': 'data/stories/3sonnets.vrs',
#                'size': 2433},
#              { 'handle': None,
#                'name': '3student.txt',
#                'path': 'data/stories/3student.txt',
#                'size': 36368},
#              { 'handle': None,
#                'name': '3wishes.txt',
#                'path': 'data/stories/3wishes.txt',
#                'size': 4351},
#              { 'handle': None,
#                'name': '4moons.txt',
#                'path': 'data/stories/4moons.txt',
#                'size': 15702},
#              { 'handle': None,
#                'name': '5orange.txt',
#                'path': 'data/stories/5orange.txt',
#                'size': 40995},
#              { 'handle': None,
#                'name': '6ablemen.txt',
#                'path': 'data/stories/6ablemen.txt',
#                'size': 6948},
#              { 'handle': None,
#                'name': '6napolen.txt',
#                'path': 'data/stories/6napolen.txt',
#                'size': 46478},
#              { 'handle': None,
#                'name': '7oldsamr.txt',
#                'path': 'data/stories/7oldsamr.txt',
#                'size': 2753},
#              { 'handle': None,
#                'name': '7voysinb.txt',
#                'path': 'data/stories/7voysinb.txt',
#                'size': 40792},
#              { 'handle': None,
#                'name': 'ab40thv.txt',
#                'path': 'data/stories/ab40thv.txt',
#                'size': 11850},
#              { 'handle': None,
#                'name': 'abbey.txt',
#                'path': 'data/stories/abbey.txt',
#                'size': 50426},
#              { 'handle': None,
#                'name': 'abyss.txt',
#                'path': 'data/stories/abyss.txt',
#                'size': 6558},
#              { 'handle': None,
#                'name': 'adler.txt',
#                'path': 'data/stories/adler.txt',
#                'size': 12778},
#              { 'handle': None,
#                'name': 'adv_alad.txt',
#                'path': 'data/stories/adv_alad.txt',
#                'size': 9908},
#              { 'handle': None,
#                'name': 'advsayed.txt',
#                'path': 'data/stories/advsayed.txt',
#                'size': 10019},
#              { 'handle': None,
#                'name': 'advtthum.txt',
#                'path': 'data/stories/advtthum.txt',
#                'size': 4373},
#              { 'handle': None,
#                'name': 'aesop11.txt',
#                'path': 'data/stories/aesop11.txt',
#                'size': 229320},
#              { 'handle': None,
#                'name': 'aesopa10.txt',
#                'path': 'data/stories/aesopa10.txt',
#                'size': 66376},
#              { 'handle': None,
#                'name': 'aircon.txt',
#                'path': 'data/stories/aircon.txt',
#                'size': 2517},
#              { 'handle': None,
#                'name': 'aisle.six',
#                'path': 'data/stories/aisle.six',
#                'size': 4736},
#              { 'handle': None,
#                'name': 'aislesix.txt',
#                'path': 'data/stories/aislesix.txt',
#                'size': 4815},
#              { 'handle': None,
#                'name': 'alad10.txt',
#                'path': 'data/stories/alad10.txt',
#                'size': 29051},
#              { 'handle': None,
#                'name': 'alissadl.txt',
#                'path': 'data/stories/alissadl.txt',
#                'size': 2169},
#              { 'handle': None,
#                'name': 'altside.hum',
#                'path': 'data/stories/altside.hum',
#                'size': 29231},
#              { 'handle': None,
#                'name': 'aluminum.hum',
#                'path': 'data/stories/aluminum.hum',
#                'size': 11596},
#              { 'handle': None,
#                'name': 'aminegg.txt',
#                'path': 'data/stories/aminegg.txt',
#                'size': 1987},
#              { 'handle': None,
#                'name': 'angelfur.hum',
#                'path': 'data/stories/angelfur.hum',
#                'size': 13376},
#              { 'handle': None,
#                'name': 'angry_ca.txt',
#                'path': 'data/stories/angry_ca.txt',
#                'size': 6648},
#              { 'handle': None,
#                'name': 'antcrick.txt',
#                'path': 'data/stories/antcrick.txt',
#                'size': 2035},
#              { 'handle': None,
#                'name': 'aquith.txt',
#                'path': 'data/stories/aquith.txt',
#                'size': 50520},
#              { 'handle': None,
#                'name': 'arcadia.sty',
#                'path': 'data/stories/arcadia.sty',
#                'size': 64484},
#              { 'handle': None,
#                'name': 'archive',
#                'path': 'data/stories/archive',
#                'size': 163840},
#              { 'handle': None,
#                'name': 'arctic.txt',
#                'path': 'data/stories/arctic.txt',
#                'size': 30964},
#              { 'handle': None,
#                'name': 'asop',
#                'path': 'data/stories/asop',
#                'size': 2037},
#              { 'handle': None,
#                'name': 'assorted.txt',
#                'path': 'data/stories/assorted.txt',
#                'size': 12535},
#              { 'handle': None,
#                'name': 'bagel.man',
#                'path': 'data/stories/bagel.man',
#                'size': 5888},
#              { 'handle': None,
#                'name': 'bagelman.txt',
#                'path': 'data/stories/bagelman.txt',
#                'size': 5892},
#              { 'handle': None,
#                'name': 'batlslau.txt',
#                'path': 'data/stories/batlslau.txt',
#                'size': 101404},
#              { 'handle': None,
#                'name': 'beast.asc',
#                'path': 'data/stories/beast.asc',
#                'size': 52273},
#              { 'handle': None,
#                'name': 'beautbst.txt',
#                'path': 'data/stories/beautbst.txt',
#                'size': 7543},
#              { 'handle': None,
#                'name': 'beggars.txt',
#                'path': 'data/stories/beggars.txt',
#                'size': 118389},
#              { 'handle': None,
#                'name': 'bern',
#                'path': 'data/stories/bern',
#                'size': 2615},
#              { 'handle': None,
#                'name': 'berternie.txt',
#                'path': 'data/stories/berternie.txt',
#                'size': 3967},
#              { 'handle': None,
#                'name': 'bestwish',
#                'path': 'data/stories/bestwish',
#                'size': 2867},
#              { 'handle': None,
#                'name': 'beyond.hum',
#                'path': 'data/stories/beyond.hum',
#                'size': 9789},
#              { 'handle': None,
#                'name': 'bgb.txt',
#                'path': 'data/stories/bgb.txt',
#                'size': 3578},
#              { 'handle': None,
#                'name': 'bgcspoof.txt',
#                'path': 'data/stories/bgcspoof.txt',
#                'size': 20361},
#              { 'handle': None,
#                'name': 'bigred.hum',
#                'path': 'data/stories/bigred.hum',
#                'size': 10356},
#              { 'handle': None,
#                'name': 'bishop00.txt',
#                'path': 'data/stories/bishop00.txt',
#                'size': 83681},
#              { 'handle': None,
#                'name': 'blabnove.hum',
#                'path': 'data/stories/blabnove.hum',
#                'size': 43263},
#              { 'handle': None,
#                'name': 'blabnove.txt',
#                'path': 'data/stories/blabnove.txt',
#                'size': 43182},
#              { 'handle': None,
#                'name': 'blackp.txt',
#                'path': 'data/stories/blackp.txt',
#                'size': 45211},
#              { 'handle': None,
#                'name': 'blackrdr',
#                'path': 'data/stories/blackrdr',
#                'size': 4148},
#              { 'handle': None,
#                'name': 'blak',
#                'path': 'data/stories/blak',
#                'size': 9951},
#              { 'handle': None,
#                'name': 'blasters.fic',
#                'path': 'data/stories/blasters.fic',
#                'size': 1882},
#              { 'handle': None,
#                'name': 'blh.txt',
#                'path': 'data/stories/blh.txt',
#                'size': 18604},
#              { 'handle': None,
#                'name': 'blind.txt',
#                'path': 'data/stories/blind.txt',
#                'size': 7108},
#              { 'handle': None,
#                'name': 'blossom.pom',
#                'path': 'data/stories/blossom.pom',
#                'size': 1287},
#              { 'handle': None,
#                'name': 'blue',
#                'path': 'data/stories/blue',
#                'size': 21423},
#              { 'handle': None,
#                'name': 'bluebrd.txt',
#                'path': 'data/stories/bluebrd.txt',
#                'size': 7026},
#              { 'handle': None,
#                'name': 'bookem.1',
#                'path': 'data/stories/bookem.1',
#                'size': 8735},
#              { 'handle': None,
#                'name': 'bookem2',
#                'path': 'data/stories/bookem2',
#                'size': 10620},
#              { 'handle': None,
#                'name': 'bookem3',
#                'path': 'data/stories/bookem3',
#                'size': 15585},
#              { 'handle': None,
#                'name': 'brain.damage',
#                'path': 'data/stories/brain.damage',
#                'size': 13472},
#              { 'handle': None,
#                'name': 'bram',
#                'path': 'data/stories/bram',
#                'size': 3835},
#              { 'handle': None,
#                'name': 'bran',
#                'path': 'data/stories/bran',
#                'size': 6914},
#              { 'handle': None,
#                'name': 'breaks1.asc',
#                'path': 'data/stories/breaks1.asc',
#                'size': 151858},
#              { 'handle': None,
#                'name': 'breaks2.asc',
#                'path': 'data/stories/breaks2.asc',
#                'size': 143725},
#              { 'handle': None,
#                'name': 'breaks3.asc',
#                'path': 'data/stories/breaks3.asc',
#                'size': 106680},
#              { 'handle': None,
#                'name': 'bruce-p.txt',
#                'path': 'data/stories/bruce-p.txt',
#                'size': 61792},
#              { 'handle': None,
#                'name': 'buggy.txt',
#                'path': 'data/stories/buggy.txt',
#                'size': 4376},
#              { 'handle': None,
#                'name': 'buldetal.txt',
#                'path': 'data/stories/buldetal.txt',
#                'size': 5395},
#              { 'handle': None,
#                'name': 'buldream.txt',
#                'path': 'data/stories/buldream.txt',
#                'size': 12089},
#              { 'handle': None,
#                'name': 'bulfelis.txt',
#                'path': 'data/stories/bulfelis.txt',
#                'size': 12474},
#              { 'handle': None,
#                'name': 'bulhuntr.txt',
#                'path': 'data/stories/bulhuntr.txt',
#                'size': 19995},
#              { 'handle': None,
#                'name': 'bulironb.txt',
#                'path': 'data/stories/bulironb.txt',
#                'size': 11842},
#              { 'handle': None,
#                'name': 'bullove.txt',
#                'path': 'data/stories/bullove.txt',
#                'size': 4136},
#              { 'handle': None,
#                'name': 'bulmrx.txt',
#                'path': 'data/stories/bulmrx.txt',
#                'size': 57265},
#              { 'handle': None,
#                'name': 'bulnland.txt',
#                'path': 'data/stories/bulnland.txt',
#                'size': 7517},
#              { 'handle': None,
#                'name': 'bulnoopt.txt',
#                'path': 'data/stories/bulnoopt.txt',
#                'size': 7502},
#              { 'handle': None,
#                'name': 'bulolli1.txt',
#                'path': 'data/stories/bulolli1.txt',
#                'size': 3960},
#              { 'handle': None,
#                'name': 'bulolli2.txt',
#                'path': 'data/stories/bulolli2.txt',
#                'size': 3383},
#              { 'handle': None,
#                'name': 'bulphrek.txt',
#                'path': 'data/stories/bulphrek.txt',
#                'size': 47098},
#              { 'handle': None,
#                'name': 'bulprint.txt',
#                'path': 'data/stories/bulprint.txt',
#                'size': 33768},
#              { 'handle': None,
#                'name': 'bulwer.lytton',
#                'path': 'data/stories/bulwer.lytton',
#                'size': 5737},
#              { 'handle': None,
#                'name': 'bulzork1.txt',
#                'path': 'data/stories/bulzork1.txt',
#                'size': 24576},
#              { 'handle': None,
#                'name': 'bumm',
#                'path': 'data/stories/bumm',
#                'size': 12194},
#              { 'handle': None,
#                'name': 'bureau.txt',
#                'path': 'data/stories/bureau.txt',
#                'size': 158330},
#              { 'handle': None,
#                'name': 'burintrv.66',
#                'path': 'data/stories/burintrv.66',
#                'size': 15275},
#              { 'handle': None,
#                'name': 'burintrv.78',
#                'path': 'data/stories/burintrv.78',
#                'size': 12183},
#              { 'handle': None,
#                'name': 'burintrv.92',
#                'path': 'data/stories/burintrv.92',
#                'size': 26710},
#              { 'handle': None,
#                'name': 'burltrs',
#                'path': 'data/stories/burltrs',
#                'size': 2232},
#              { 'handle': None,
#                'name': 'burn',
#                'path': 'data/stories/burn',
#                'size': 2598},
#              { 'handle': None,
#                'name': 'cabin.txt',
#                'path': 'data/stories/cabin.txt',
#                'size': 2339},
#              { 'handle': None,
#                'name': 'cameloto.hum',
#                'path': 'data/stories/cameloto.hum',
#                'size': 1956},
#              { 'handle': None,
#                'name': 'campfire.txt',
#                'path': 'data/stories/campfire.txt',
#                'size': 2786},
#              { 'handle': None,
#                'name': 'candle.hum',
#                'path': 'data/stories/candle.hum',
#                'size': 19409},
#              { 'handle': None,
#                'name': 'cardcnt.txt',
#                'path': 'data/stories/cardcnt.txt',
#                'size': 39098},
#              { 'handle': None,
#                'name': 'ccm.txt',
#                'path': 'data/stories/ccm.txt',
#                'size': 2233},
#              { 'handle': None,
#                'name': 'charlie.txt',
#                'path': 'data/stories/charlie.txt',
#                'size': 21045},
#              { 'handle': None,
#                'name': 'chik',
#                'path': 'data/stories/chik',
#                'size': 9990},
#              { 'handle': None,
#                'name': 'clevdonk.txt',
#                'path': 'data/stories/clevdonk.txt',
#                'size': 1968},
#              { 'handle': None,
#                'name': 'clon',
#                'path': 'data/stories/clon',
#                'size': 22943},
#              { 'handle': None,
#                'name': 'cmoutmou.txt',
#                'path': 'data/stories/cmoutmou.txt',
#                'size': 3634},
#              { 'handle': None,
#                'name': 'comp',
#                'path': 'data/stories/comp',
#                'size': 11016},
#              { 'handle': None,
#                'name': 'confilct.fun',
#                'path': 'data/stories/confilct.fun',
#                'size': 2469},
#              { 'handle': None,
#                'name': 'consumdr.hum',
#                'path': 'data/stories/consumdr.hum',
#                'size': 23989},
#              { 'handle': None,
#                'name': 'contrad1.hum',
#                'path': 'data/stories/contrad1.hum',
#                'size': 1397},
#              { 'handle': None,
#                'name': 'cooldark.sto',
#                'path': 'data/stories/cooldark.sto',
#                'size': 146795},
#              { 'handle': None,
#                'name': 'cooldark.txt',
#                'path': 'data/stories/cooldark.txt',
#                'size': 146795},
#              { 'handle': None,
#                'name': 'corcor.hum',
#                'path': 'data/stories/corcor.hum',
#                'size': 40142},
#              { 'handle': None,
#                'name': 'cow.exploder',
#                'path': 'data/stories/cow.exploder',
#                'size': 7552},
#              { 'handle': None,
#                'name': 'crabhern.txt',
#                'path': 'data/stories/crabhern.txt',
#                'size': 2181},
#              { 'handle': None,
#                'name': 'crazy.hum',
#                'path': 'data/stories/crazy.hum',
#                'size': 65666},
#              { 'handle': None,
#                'name': 'cum',
#                'path': 'data/stories/cum',
#                'size': 6757},
#              { 'handle': None,
#                'name': 'curious.george',
#                'path': 'data/stories/curious.george',
#                'size': 4096},
#              { 'handle': None,
#                'name': 'cybersla.txt',
#                'path': 'data/stories/cybersla.txt',
#                'size': 415872},
#              { 'handle': None,
#                'name': 'dakota.txt',
#                'path': 'data/stories/dakota.txt',
#                'size': 151783},
#              { 'handle': None,
#                'name': 'dan',
#                'path': 'data/stories/dan',
#                'size': 15266},
#              { 'handle': None,
#                'name': 'darkness.txt',
#                'path': 'data/stories/darkness.txt',
#                'size': 217124},
#              { 'handle': None,
#                'name': 'day.in.mcdonald',
#                'path': 'data/stories/day.in.mcdonald',
#                'size': 6784},
#              { 'handle': None,
#                'name': 'deal',
#                'path': 'data/stories/deal',
#                'size': 10658},
#              { 'handle': None,
#                'name': 'deathmrs.d',
#                'path': 'data/stories/deathmrs.d',
#                'size': 5163},
#              { 'handle': None,
#                'name': 'deer.txt',
#                'path': 'data/stories/deer.txt',
#                'size': 4295},
#              { 'handle': None,
#                'name': 'descent.poe',
#                'path': 'data/stories/descent.poe',
#                'size': 39201},
#              { 'handle': None,
#                'name': 'diaryflf.txt',
#                'path': 'data/stories/diaryflf.txt',
#                'size': 47512},
#              { 'handle': None,
#                'name': 'dicegame.txt',
#                'path': 'data/stories/dicegame.txt',
#                'size': 9367},
#              { 'handle': None,
#                'name': 'dicksong.txt',
#                'path': 'data/stories/dicksong.txt',
#                'size': 8192},
#              { 'handle': None,
#                'name': 'disco.be.fun',
#                'path': 'data/stories/disco.be.fun',
#                'size': 3840},
#              { 'handle': None,
#                'name': 'discocanbefun.txt',
#                'path': 'data/stories/discocanbefun.txt',
#                'size': 3921},
#              { 'handle': None,
#                'name': 'domain.poe',
#                'path': 'data/stories/domain.poe',
#                'size': 36642},
#              { 'handle': None,
#                'name': 'dopedenn.txt',
#                'path': 'data/stories/dopedenn.txt',
#                'size': 8887},
#              { 'handle': None,
#                'name': 'dskool.txt',
#                'path': 'data/stories/dskool.txt',
#                'size': 84178},
#              { 'handle': None,
#                'name': 'dtruck.txt',
#                'path': 'data/stories/dtruck.txt',
#                'size': 8862},
#              { 'handle': None,
#                'name': 'dwar',
#                'path': 'data/stories/dwar',
#                'size': 4602},
#              { 'handle': None,
#                'name': 'elite.app',
#                'path': 'data/stories/elite.app',
#                'size': 109637},
#              { 'handle': None,
#                'name': 'elveshoe.txt',
#                'path': 'data/stories/elveshoe.txt',
#                'size': 2683},
#              { 'handle': None,
#                'name': 'emperor3.txt',
#                'path': 'data/stories/emperor3.txt',
#                'size': 8704},
#              { 'handle': None,
#                'name': 'empnclot.txt',
#                'path': 'data/stories/empnclot.txt',
#                'size': 6198},
#              { 'handle': None,
#                'name': 'empsjowk.txt',
#                'path': 'data/stories/empsjowk.txt',
#                'size': 7474},
#              { 'handle': None,
#                'name': 'empty.txt',
#                'path': 'data/stories/empty.txt',
#                'size': 48849},
#              { 'handle': None,
#                'name': 'enc',
#                'path': 'data/stories/enc',
#                'size': 12888},
#              { 'handle': None,
#                'name': 'encamp01.txt',
#                'path': 'data/stories/encamp01.txt',
#                'size': 4096},
#              { 'handle': None,
#                'name': 'enchdup.hum',
#                'path': 'data/stories/enchdup.hum',
#                'size': 95232},
#              { 'handle': None,
#                'name': 'enginer.txt',
#                'path': 'data/stories/enginer.txt',
#                'size': 46035},
#              { 'handle': None,
#                'name': 'enya_trn.txt',
#                'path': 'data/stories/enya_trn.txt',
#                'size': 27011},
#              { 'handle': None,
#                'name': 'excerpt.hum',
#                'path': 'data/stories/excerpt.hum',
#                'size': 5589},
#              { 'handle': None,
#                'name': 'excerpt.txt',
#                'path': 'data/stories/excerpt.txt',
#                'size': 6036},
#              { 'handle': None,
#                'name': 'eyeargon.hum',
#                'path': 'data/stories/eyeargon.hum',
#                'size': 70912},
#              { 'handle': None,
#                'name': 'ezoff',
#                'path': 'data/stories/ezoff',
#                'size': 14835},
#              { 'handle': None,
#                'name': 'fable.txt',
#                'path': 'data/stories/fable.txt',
#                'size': 12199},
#              { 'handle': None,
#                'name': 'fantas.hum',
#                'path': 'data/stories/fantas.hum',
#                'size': 10454},
#              { 'handle': None,
#                'name': 'fantasy.hum',
#                'path': 'data/stories/fantasy.hum',
#                'size': 16428},
#              { 'handle': None,
#                'name': 'fantasy.txt',
#                'path': 'data/stories/fantasy.txt',
#                'size': 16347},
#              { 'handle': None,
#                'name': 'fea1',
#                'path': 'data/stories/fea1',
#                'size': 4130},
#              { 'handle': None,
#                'name': 'fea2',
#                'path': 'data/stories/fea2',
#                'size': 6766},
#              { 'handle': None,
#                'name': 'fea3',
#                'path': 'data/stories/fea3',
#                'size': 3111},
#              { 'handle': None,
#                'name': 'fear.hum',
#                'path': 'data/stories/fear.hum',
#                'size': 6750},
#              { 'handle': None,
#                'name': 'fearmnky',
#                'path': 'data/stories/fearmnky',
#                'size': 1309},
#              { 'handle': None,
#                'name': 'fgoose.txt',
#                'path': 'data/stories/fgoose.txt',
#                'size': 75471},
#              { 'handle': None,
#                'name': 'fic1',
#                'path': 'data/stories/fic1',
#                'size': 46084},
#              { 'handle': None,
#                'name': 'fic2',
#                'path': 'data/stories/fic2',
#                'size': 36396},
#              { 'handle': None,
#                'name': 'fic3',
#                'path': 'data/stories/fic3',
#                'size': 23996},
#              { 'handle': None,
#                'name': 'fic4',
#                'path': 'data/stories/fic4',
#                'size': 14549},
#              { 'handle': None,
#                'name': 'fic5',
#                'path': 'data/stories/fic5',
#                'size': 31809},
#              { 'handle': None,
#                'name': 'fic7',
#                'path': 'data/stories/fic7',
#                'size': 12410},
#              { 'handle': None,
#                'name': 'fish.txt',
#                'path': 'data/stories/fish.txt',
#                'size': 2725},
#              { 'handle': None,
#                'name': 'fleas.txt',
#                'path': 'data/stories/fleas.txt',
#                'size': 3120},
#              { 'handle': None,
#                'name': 'flktrp.txt',
#                'path': 'data/stories/flktrp.txt',
#                'size': 7320},
#              { 'handle': None,
#                'name': 'floc',
#                'path': 'data/stories/floc',
#                'size': 19364},
#              { 'handle': None,
#                'name': 'floobs.txt',
#                'path': 'data/stories/floobs.txt',
#                'size': 5126},
#              { 'handle': None,
#                'name': 'flute.txt',
#                'path': 'data/stories/flute.txt',
#                'size': 3038},
#              { 'handle': None,
#                'name': 'flytrunk.txt',
#                'path': 'data/stories/flytrunk.txt',
#                'size': 2007},
#              { 'handle': None,
#                'name': 'forgotte',
#                'path': 'data/stories/forgotte',
#                'size': 77918},
#              { 'handle': None,
#                'name': 'fourth.fic',
#                'path': 'data/stories/fourth.fic',
#                'size': 3815},
#              { 'handle': None,
#                'name': 'fowl.death',
#                'path': 'data/stories/fowl.death',
#                'size': 3328},
#              { 'handle': None,
#                'name': 'foxncrow.txt',
#                'path': 'data/stories/foxncrow.txt',
#                'size': 2179},
#              { 'handle': None,
#                'name': 'foxngrap.txt',
#                'path': 'data/stories/foxngrap.txt',
#                'size': 2368},
#              { 'handle': None,
#                'name': 'foxnstrk.txt',
#                'path': 'data/stories/foxnstrk.txt',
#                'size': 2079},
#              { 'handle': None,
#                'name': 'fran',
#                'path': 'data/stories/fran',
#                'size': 13488},
#              { 'handle': None,
#                'name': 'fred.txt',
#                'path': 'data/stories/fred.txt',
#                'size': 13304},
#              { 'handle': None,
#                'name': 'freeman.fil',
#                'path': 'data/stories/freeman.fil',
#                'size': 11352},
#              { 'handle': None,
#                'name': 'friend.s',
#                'path': 'data/stories/friend.s',
#                'size': 6855},
#              { 'handle': None,
#                'name': 'friends.txt',
#                'path': 'data/stories/friends.txt',
#                'size': 76566},
#              { 'handle': None,
#                'name': 'frogp.txt',
#                'path': 'data/stories/frogp.txt',
#                'size': 5311},
#              { 'handle': None,
#                'name': 'frum',
#                'path': 'data/stories/frum',
#                'size': 4219},
#              { 'handle': None,
#                'name': 'game.txt',
#                'path': 'data/stories/game.txt',
#                'size': 10638},
#              { 'handle': None,
#                'name': 'gatherng.txt',
#                'path': 'data/stories/gatherng.txt',
#                'size': 10397},
#              { 'handle': None,
#                'name': 'gay',
#                'path': 'data/stories/gay',
#                'size': 10523},
#              { 'handle': None,
#                'name': 'gemdra.txt',
#                'path': 'data/stories/gemdra.txt',
#                'size': 4479},
#              { 'handle': None,
#                'name': 'ghost',
#                'path': 'data/stories/ghost',
#                'size': 16110},
#              { 'handle': None,
#                'name': 'girl',
#                'path': 'data/stories/girl',
#                'size': 14273},
#              { 'handle': None,
#                'name': 'girlclub.txt',
#                'path': 'data/stories/girlclub.txt',
#                'size': 52403},
#              { 'handle': None,
#                'name': 'glimpse1.txt',
#                'path': 'data/stories/glimpse1.txt',
#                'size': 3056},
#              { 'handle': None,
#                'name': 'gloves.txt',
#                'path': 'data/stories/gloves.txt',
#                'size': 1679},
#              { 'handle': None,
#                'name': 'gold3ber.txt',
#                'path': 'data/stories/gold3ber.txt',
#                'size': 5558},
#              { 'handle': None,
#                'name': 'goldbug.poe',
#                'path': 'data/stories/goldbug.poe',
#                'size': 78372},
#              { 'handle': None,
#                'name': 'goldenp.txt',
#                'path': 'data/stories/goldenp.txt',
#                'size': 49790},
#              { 'handle': None,
#                'name': 'goldfish.txt',
#                'path': 'data/stories/goldfish.txt',
#                'size': 4948},
#              { 'handle': None,
#                'name': 'goldgoos.txt',
#                'path': 'data/stories/goldgoos.txt',
#                'size': 5003},
#              { 'handle': None,
#                'name': 'grav',
#                'path': 'data/stories/grav',
#                'size': 22515},
#              { 'handle': None,
#                'name': 'graymare.txt',
#                'path': 'data/stories/graymare.txt',
#                'size': 3211},
#              { 'handle': None,
#                'name': 'greatlrn.leg',
#                'path': 'data/stories/greatlrn.leg',
#                'size': 18458},
#              { 'handle': None,
#                'name': 'greedog.txt',
#                'path': 'data/stories/greedog.txt',
#                'size': 897},
#              { 'handle': None,
#                'name': 'gulliver.txt',
#                'path': 'data/stories/gulliver.txt',
#                'size': 708064},
#              { 'handle': None,
#                'name': 'hansgrtl.txt',
#                'path': 'data/stories/hansgrtl.txt',
#                'size': 6981},
#              { 'handle': None,
#                'name': 'hareleph.txt',
#                'path': 'data/stories/hareleph.txt',
#                'size': 1696},
#              { 'handle': None,
#                'name': 'hareporc.txt',
#                'path': 'data/stories/hareporc.txt',
#                'size': 4044},
#              { 'handle': None,
#                'name': 'haretort.txt',
#                'path': 'data/stories/haretort.txt',
#                'size': 2271},
#              { 'handle': None,
#                'name': 'healer.txt',
#                'path': 'data/stories/healer.txt',
#                'size': 16935},
#              { 'handle': None,
#                'name': 'hell4.txt',
#                'path': 'data/stories/hell4.txt',
#                'size': 5983},
#              { 'handle': None,
#                'name': 'hellmach.txt',
#                'path': 'data/stories/hellmach.txt',
#                'size': 110143},
#              { 'handle': None,
#                'name': 'helmfuse.txt',
#                'path': 'data/stories/helmfuse.txt',
#                'size': 2122},
#              { 'handle': None,
#                'name': 'hils',
#                'path': 'data/stories/hils',
#                'size': 15359},
#              { 'handle': None,
#                'name': 'history5.txt',
#                'path': 'data/stories/history5.txt',
#                'size': 140322},
#              { 'handle': None,
#                'name': 'hitch2.txt',
#                'path': 'data/stories/hitch2.txt',
#                'size': 330566},
#              { 'handle': None,
#                'name': 'hitch3.txt',
#                'path': 'data/stories/hitch3.txt',
#                'size': 327595},
#              { 'handle': None,
#                'name': 'hole2nar.txt',
#                'path': 'data/stories/hole2nar.txt',
#                'size': 3229},
#              { 'handle': None,
#                'name': 'holmesbk.txt',
#                'path': 'data/stories/holmesbk.txt',
#                'size': 29749},
#              { 'handle': None,
#                'name': 'home.fil',
#                'path': 'data/stories/home.fil',
#                'size': 7151},
#              { 'handle': None,
#                'name': 'hop-frog.poe',
#                'path': 'data/stories/hop-frog.poe',
#                'size': 21472},
#              { 'handle': None,
#                'name': 'horsdonk.txt',
#                'path': 'data/stories/horsdonk.txt',
#                'size': 2344},
#              { 'handle': None,
#                'name': 'horswolf.txt',
#                'path': 'data/stories/horswolf.txt',
#                'size': 2085},
#              { 'handle': None,
#                'name': 'hotline1.txt',
#                'path': 'data/stories/hotline1.txt',
#                'size': 3243},
#              { 'handle': None,
#                'name': 'hotline3.txt',
#                'path': 'data/stories/hotline3.txt',
#                'size': 3000},
#              { 'handle': None,
#                'name': 'hotline4.txt',
#                'path': 'data/stories/hotline4.txt',
#                'size': 3144},
#              { 'handle': None,
#                'name': 'hound-b.txt',
#                'path': 'data/stories/hound-b.txt',
#                'size': 328031},
#              { 'handle': None,
#                'name': 'how.ernie.bert',
#                'path': 'data/stories/how.ernie.bert',
#                'size': 3968},
#              { 'handle': None,
#                'name': 'idi.hum',
#                'path': 'data/stories/idi.hum',
#                'size': 19923},
#              { 'handle': None,
#                'name': 'igiv',
#                'path': 'data/stories/igiv',
#                'size': 18304},
#              { 'handle': None,
#                'name': 'imagin.hum',
#                'path': 'data/stories/imagin.hum',
#                'size': 11169},
#              { 'handle': None,
#                'name': 'immortal',
#                'path': 'data/stories/immortal',
#                'size': 12264},
#              { 'handle': None,
#                'name': 'immorti.hum',
#                'path': 'data/stories/immorti.hum',
#                'size': 18491},
#              { 'handle': None,
#                'name': 'imonly17.txt',
#                'path': 'data/stories/imonly17.txt',
#                'size': 3590},
#              { 'handle': None,
#                'name': 'index.html',
#                'path': 'data/stories/index.html',
#                'size': 62395},
#              { 'handle': None,
#                'name': 'inter',
#                'path': 'data/stories/inter',
#                'size': 16939},
#              { 'handle': None,
#                'name': 'island.poe',
#                'path': 'data/stories/island.poe',
#                'size': 11922},
#              { 'handle': None,
#                'name': 'jackbstl.txt',
#                'path': 'data/stories/jackbstl.txt',
#                'size': 9475},
#              { 'handle': None,
#                'name': 'jackmac.fic',
#                'path': 'data/stories/jackmac.fic',
#                'size': 14134},
#              { 'handle': None,
#                'name': 'jaynejob.asc',
#                'path': 'data/stories/jaynejob.asc',
#                'size': 6158},
#              { 'handle': None,
#                'name': 'jerichms.hum',
#                'path': 'data/stories/jerichms.hum',
#                'size': 5851},
#              { 'handle': None,
#                'name': 'jim.asc',
#                'path': 'data/stories/jim.asc',
#                'size': 1612},
#              { 'handle': None,
#                'name': 'keeping.insanit',
#                'path': 'data/stories/keeping.insanit',
#                'size': 9856},
#              { 'handle': None,
#                'name': 'keepmodu.txt',
#                'path': 'data/stories/keepmodu.txt',
#                'size': 88567},
#              { 'handle': None,
#                'name': 'kharian.txt',
#                'path': 'data/stories/kharian.txt',
#                'size': 8459},
#              { 'handle': None,
#                'name': 'kneeslapper',
#                'path': 'data/stories/kneeslapper',
#                'size': 1024},
#              { 'handle': None,
#                'name': 'kneeslapper.txt',
#                'path': 'data/stories/kneeslapper.txt',
#                'size': 1051},
#              { 'handle': None,
#                'name': 'knuckle.txt',
#                'path': 'data/stories/knuckle.txt',
#                'size': 23202},
#              { 'handle': None,
#                'name': 'korea.s',
#                'path': 'data/stories/korea.s',
#                'size': 16019},
#              { 'handle': None,
#                'name': 'kzap.txt',
#                'path': 'data/stories/kzap.txt',
#                'size': 10120},
#              { 'handle': None,
#                'name': 'ladylust.hum',
#                'path': 'data/stories/ladylust.hum',
#                'size': 3794},
#              { 'handle': None,
#                'name': 'lament.txt',
#                'path': 'data/stories/lament.txt',
#                'size': 7123},
#              { 'handle': None,
#                'name': 'lgoldbrd.txt',
#                'path': 'data/stories/lgoldbrd.txt',
#                'size': 1982},
#              { 'handle': None,
#                'name': 'life.txt',
#                'path': 'data/stories/life.txt',
#                'size': 867},
#              { 'handle': None,
#                'name': 'lil',
#                'path': 'data/stories/lil',
#                'size': 13764},
#              { 'handle': None,
#                'name': 'lionbird',
#                'path': 'data/stories/lionbird',
#                'size': 6605},
#              { 'handle': None,
#                'name': 'lionmane.txt',
#                'path': 'data/stories/lionmane.txt',
#                'size': 40548},
#              { 'handle': None,
#                'name': 'lionmosq.txt',
#                'path': 'data/stories/lionmosq.txt',
#                'size': 1892},
#              { 'handle': None,
#                'name': 'lionwar.txt',
#                'path': 'data/stories/lionwar.txt',
#                'size': 1749},
#              { 'handle': None,
#                'name': 'lmermaid.txt',
#                'path': 'data/stories/lmermaid.txt',
#                'size': 12445},
#              { 'handle': None,
#                'name': 'lmtchgrl.txt',
#                'path': 'data/stories/lmtchgrl.txt',
#                'size': 3215},
#              { 'handle': None,
#                'name': 'long1-3.txt',
#                'path': 'data/stories/long1-3.txt',
#                'size': 73544},
#              { 'handle': None,
#                'name': 'lpeargrl.txt',
#                'path': 'data/stories/lpeargrl.txt',
#                'size': 4417},
#              { 'handle': None,
#                'name': 'lrrhood.txt',
#                'path': 'data/stories/lrrhood.txt',
#                'size': 5738},
#              { 'handle': None,
#                'name': 'ltp',
#                'path': 'data/stories/ltp',
#                'size': 20325},
#              { 'handle': None,
#                'name': 'luf',
#                'path': 'data/stories/luf',
#                'size': 2691},
#              { 'handle': None,
#                'name': 'lure.txt',
#                'path': 'data/stories/lure.txt',
#                'size': 25546},
#              { 'handle': None,
#                'name': 'mario.txt',
#                'path': 'data/stories/mario.txt',
#                'size': 5696},
#              { 'handle': None,
#                'name': 'mattress.txt',
#                'path': 'data/stories/mattress.txt',
#                'size': 13120},
#              { 'handle': None,
#                'name': 'mazarin.txt',
#                'path': 'data/stories/mazarin.txt',
#                'size': 32321},
#              { 'handle': None,
#                'name': 'mcdonaldl.txt',
#                'path': 'data/stories/mcdonaldl.txt',
#                'size': 6879},
#              { 'handle': None,
#                'name': 'melissa.txt',
#                'path': 'data/stories/melissa.txt',
#                'size': 6509},
#              { 'handle': None,
#                'name': 'mike.txt',
#                'path': 'data/stories/mike.txt',
#                'size': 712},
#              { 'handle': None,
#                'name': 'mindprob.txt',
#                'path': 'data/stories/mindprob.txt',
#                'size': 12069},
#              { 'handle': None,
#                'name': 'mindwar',
#                'path': 'data/stories/mindwar',
#                'size': 5424},
#              { 'handle': None,
#                'name': 'missing.txt',
#                'path': 'data/stories/missing.txt',
#                'size': 45497},
#              { 'handle': None,
#                'name': 'modemhippy.txt',
#                'path': 'data/stories/modemhippy.txt',
#                'size': 2604},
#              { 'handle': None,
#                'name': 'monkking.txt',
#                'path': 'data/stories/monkking.txt',
#                'size': 2703},
#              { 'handle': None,
#                'name': 'monksol.txt',
#                'path': 'data/stories/monksol.txt',
#                'size': 16278},
#              { 'handle': None,
#                'name': 'mouslion.txt',
#                'path': 'data/stories/mouslion.txt',
#                'size': 1957},
#              { 'handle': None,
#                'name': 'mtinder.txt',
#                'path': 'data/stories/mtinder.txt',
#                'size': 5057},
#              { 'handle': None,
#                'name': 'musgrave.txt',
#                'path': 'data/stories/musgrave.txt',
#                'size': 42029},
#              { 'handle': None,
#                'name': 'musibrem.txt',
#                'path': 'data/stories/musibrem.txt',
#                'size': 3579},
#              { 'handle': None,
#                'name': 'mydream.txt',
#                'path': 'data/stories/mydream.txt',
#                'size': 2798},
#              { 'handle': None,
#                'name': 'myeyes',
#                'path': 'data/stories/myeyes',
#                'size': 2304},
#              { 'handle': None,
#                'name': 'narciss.txt',
#                'path': 'data/stories/narciss.txt',
#                'size': 1383},
#              { 'handle': None,
#                'name': 'nigel.1',
#                'path': 'data/stories/nigel.1',
#                'size': 4725},
#              { 'handle': None,
#                'name': 'nigel.10',
#                'path': 'data/stories/nigel.10',
#                'size': 16096},
#              { 'handle': None,
#                'name': 'nigel.2',
#                'path': 'data/stories/nigel.2',
#                'size': 9431},
#              { 'handle': None,
#                'name': 'nigel.3',
#                'path': 'data/stories/nigel.3',
#                'size': 9668},
#              { 'handle': None,
#                'name': 'nigel.4',
#                'path': 'data/stories/nigel.4',
#                'size': 8845},
#              { 'handle': None,
#                'name': 'nigel.5',
#                'path': 'data/stories/nigel.5',
#                'size': 6722},
#              { 'handle': None,
#                'name': 'nigel.6',
#                'path': 'data/stories/nigel.6',
#                'size': 9980},
#              { 'handle': None,
#                'name': 'nigel.7',
#                'path': 'data/stories/nigel.7',
#                'size': 8226},
#              { 'handle': None,
#                'name': 'nihgel_8.9',
#                'path': 'data/stories/nihgel_8.9',
#                'size': 16339},
#              { 'handle': None,
#                'name': 'nitepeek.sto',
#                'path': 'data/stories/nitepeek.sto',
#                'size': 14156},
#              { 'handle': None,
#                'name': 'non2',
#                'path': 'data/stories/non2',
#                'size': 2963},
#              { 'handle': None,
#                'name': 'non3',
#                'path': 'data/stories/non3',
#                'size': 2525},
#              { 'handle': None,
#                'name': 'non4',
#                'path': 'data/stories/non4',
#                'size': 8370},
#              { 'handle': None,
#                'name': 'obstgoat.txt',
#                'path': 'data/stories/obstgoat.txt',
#                'size': 869},
#              { 'handle': None,
#                'name': 'omarsheh.txt',
#                'path': 'data/stories/omarsheh.txt',
#                'size': 8280},
#              { 'handle': None,
#                'name': 'outcast.dos',
#                'path': 'data/stories/outcast.dos',
#                'size': 216738},
#              { 'handle': None,
#                'name': 'oxfrog.txt',
#                'path': 'data/stories/oxfrog.txt',
#                'size': 1869},
#              { 'handle': None,
#                'name': 'paink-ws.txt',
#                'path': 'data/stories/paink-ws.txt',
#                'size': 23093},
#              { 'handle': None,
#                'name': 'panama.txt',
#                'path': 'data/stories/panama.txt',
#                'size': 5775},
#              { 'handle': None,
#                'name': 'parotsha.txt',
#                'path': 'data/stories/parotsha.txt',
#                'size': 7664},
#              { 'handle': None,
#                'name': 'partya.txt',
#                'path': 'data/stories/partya.txt',
#                'size': 9982},
#              { 'handle': None,
#                'name': 'paul_har.sto',
#                'path': 'data/stories/paul_har.sto',
#                'size': 3226},
#              { 'handle': None,
#                'name': 'peace.fun',
#                'path': 'data/stories/peace.fun',
#                'size': 653},
#              { 'handle': None,
#                'name': 'pepdegener.txt',
#                'path': 'data/stories/pepdegener.txt',
#                'size': 4462},
#              { 'handle': None,
#                'name': 'pepsi.degenerat',
#                'path': 'data/stories/pepsi.degenerat',
#                'size': 4480},
#              { 'handle': None,
#                'name': 'perf',
#                'path': 'data/stories/perf',
#                'size': 35939},
#              { 'handle': None,
#                'name': 'pinocch.txt',
#                'path': 'data/stories/pinocch.txt',
#                'size': 19116},
#              { 'handle': None,
#                'name': 'piracy.sto',
#                'path': 'data/stories/piracy.sto',
#                'size': 19929},
# ...
#              { 'handle': None,
#                'name': 'quot',
#                'path': 'data/stories/quot',
#                'size': 3388},
#              { 'handle': None,
#                'name': 'radar_ra.txt',
#                'path': 'data/stories/radar_ra.txt',
#                'size': 302831},
#              { 'handle': None,
#                'name': 'rainda.txt',
#                'path': 'data/stories/rainda.txt',
#                'size': 16946},
#              { 'handle': None,
#                'name': 'reality.txt',
#                'path': 'data/stories/reality.txt',
#                'size': 5761},
#              { 'handle': None,
#                'name': 'reap',
#                'path': 'data/stories/reap',
#                'size': 15152},
#              { 'handle': None,
#                'name': 'redragon.txt',
#                'path': 'data/stories/redragon.txt',
#                'size': 2563},
#              { 'handle': None,
#                'name': 'retrib.txt',
#                'path': 'data/stories/retrib.txt',
#                'size': 16581},
#              { 'handle': None,
#                'name': 'rid.txt',
#                'path': 'data/stories/rid.txt',
#                'size': 895},
#              { 'handle': None,
#                'name': 'robotech',
#                'path': 'data/stories/robotech',
#                'size': 233001},
#              { 'handle': None,
#                'name': 'rock',
#                'path': 'data/stories/rock',
#                'size': 11383},
#              { 'handle': None,
#                'name': 'rocket.sf',
#                'path': 'data/stories/rocket.sf',
#                'size': 215959},
#              { 'handle': None,
#                'name': 'roger1.txt',
#                'path': 'data/stories/roger1.txt',
#                'size': 44564},
#              { 'handle': None,
#                'name': 'running.txt',
#                'path': 'data/stories/running.txt',
#                'size': 49286},
#              { 'handle': None,
#                'name': 's&m_plot',
#                'path': 'data/stories/s&m_plot',
#                'size': 8839},
#              { 'handle': None,
#                'name': 's&m_that',
#                'path': 'data/stories/s&m_that',
#                'size': 6465},
#              { 'handle': None,
#                'name': 'safe',
#                'path': 'data/stories/safe',
#                'size': 9163},
#              { 'handle': None,
#                'name': 'sanpedr2.txt',
#                'path': 'data/stories/sanpedr2.txt',
#                'size': 7322},
#              { 'handle': None,
#                'name': 'shoscomb.txt',
#                'path': 'data/stories/shoscomb.txt',
#                'size': 34558},
#              { 'handle': None,
#                'name': 'shrdfarm.txt',
#                'path': 'data/stories/shrdfarm.txt',
#                'size': 4775},
#              { 'handle': None,
#                'name': 'shulk.txt',
#                'path': 'data/stories/shulk.txt',
#                'size': 17152},
#              { 'handle': None,
#                'name': 'sick-kid.txt',
#                'path': 'data/stories/sick-kid.txt',
#                'size': 319013},
#              { 'handle': None,
#                'name': 'sight.txt',
#                'path': 'data/stories/sight.txt',
#                'size': 10173},
#              { 'handle': None,
#                'name': 'silverb.txt',
#                'path': 'data/stories/silverb.txt',
#                'size': 54159},
#              { 'handle': None,
#                'name': 'sis',
#                'path': 'data/stories/sis',
#                'size': 9780},
#              { 'handle': None,
#                'name': 'sleprncs.txt',
#                'path': 'data/stories/sleprncs.txt',
#                'size': 6014},
#              { 'handle': None,
#                'name': 'snow.txt',
#                'path': 'data/stories/snow.txt',
#                'size': 12351},
#              { 'handle': None,
#                'name': 'snowmaid.txt',
#                'path': 'data/stories/snowmaid.txt',
#                'size': 1838},
#              { 'handle': None,
#                'name': 'snowqn1.txt',
#                'path': 'data/stories/snowqn1.txt',
#                'size': 4597},
#              { 'handle': None,
#                'name': 'social.vikings',
#                'path': 'data/stories/social.vikings',
#                'size': 6784},
#              { 'handle': None,
#                'name': 'socialvikings.txt',
#                'path': 'data/stories/socialvikings.txt',
#                'size': 6845},
#              { 'handle': None,
#                'name': 'solitary.txt',
#                'path': 'data/stories/solitary.txt',
#                'size': 43869},
#              { 'handle': None,
#                'name': 'space.txt',
#                'path': 'data/stories/space.txt',
#                'size': 5551},
#              { 'handle': None,
#                'name': 'spam.key',
#                'path': 'data/stories/spam.key',
#                'size': 7296},
#              { 'handle': None,
#                'name': 'spectacl.poe',
#                'path': 'data/stories/spectacl.poe',
#                'size': 55113},
#              { 'handle': None,
#                'name': 'spider.txt',
#                'path': 'data/stories/spider.txt',
#                'size': 4042},
#              { 'handle': None,
#                'name': 'spiders.txt',
#                'path': 'data/stories/spiders.txt',
#                'size': 8217},
#              { 'handle': None,
#                'name': 'sqzply.txt',
#                'path': 'data/stories/sqzply.txt',
#                'size': 60800},
#              { 'handle': None,
#                'name': 'sre-dark.txt',
#                'path': 'data/stories/sre-dark.txt',
#                'size': 33666},
#              { 'handle': None,
#                'name': 'stainles.ana',
#                'path': 'data/stories/stainles.ana',
#                'size': 3247},
#              { 'handle': None,
#                'name': 'stairdre.txt',
#                'path': 'data/stories/stairdre.txt',
#                'size': 5130},
#              { 'handle': None,
#                'name': 'startrek.txt',
#                'path': 'data/stories/startrek.txt',
#                'size': 8473},
#              { 'handle': None,
#                'name': 'stsgreek',
#                'path': 'data/stories/stsgreek',
#                'size': 9245},
#              { 'handle': None,
#                'name': 'sucker.txt',
#                'path': 'data/stories/sucker.txt',
#                'size': 3813},
#              { 'handle': None,
#                'name': 'sunday.txt',
#                'path': 'data/stories/sunday.txt',
#                'size': 2456},
#              { 'handle': None,
#                'name': 'superg1',
#                'path': 'data/stories/superg1',
#                'size': 50938},
#              { 'handle': None,
#                'name': 'szechuan',
#                'path': 'data/stories/szechuan',
#                'size': 4599},
#              { 'handle': None,
#                'name': 't_zone.jok',
#                'path': 'data/stories/t_zone.jok',
#                'size': 9046},
#              { 'handle': None,
#                'name': 'tailbear.txt',
#                'path': 'data/stories/tailbear.txt',
#                'size': 2695},
#              { 'handle': None,
#                'name': 'tao3.dos',
#                'path': 'data/stories/tao3.dos',
#                'size': 52914},
#              { 'handle': None,
#                'name': 'taxnovel.txt',
#                'path': 'data/stories/taxnovel.txt',
#                'size': 47601},
#              { 'handle': None,
#                'name': 'tcoa.txt',
#                'path': 'data/stories/tcoa.txt',
#                'size': 13216},
#              { 'handle': None,
#                'name': 'tctac.txt',
#                'path': 'data/stories/tctac.txt',
#                'size': 2301},
#              { 'handle': None,
#                'name': 'tearglas.txt',
#                'path': 'data/stories/tearglas.txt',
#                'size': 31407},
#              { 'handle': None,
#                'name': 'telefone.txt',
#                'path': 'data/stories/telefone.txt',
#                'size': 3405},
#              { 'handle': None,
#                'name': 'terrorbears.txt',
#                'path': 'data/stories/terrorbears.txt',
#                'size': 4816},
#              { 'handle': None,
#                'name': 'testpilo.hum',
#                'path': 'data/stories/testpilo.hum',
#                'size': 16609},
#              { 'handle': None,
#                'name': 'textfile.primer',
#                'path': 'data/stories/textfile.primer',
#                'size': 6528},
#              { 'handle': None,
#                'name': 'thanksg',
#                'path': 'data/stories/thanksg',
#                'size': 1415},
#              { 'handle': None,
#                'name': 'the-tree.txt',
#                'path': 'data/stories/the-tree.txt',
#                'size': 558},
#              { 'handle': None,
#                'name': 'thewave',
#                'path': 'data/stories/thewave',
#                'size': 14240},
#              { 'handle': None,
#                'name': 'timem.hac',
#                'path': 'data/stories/timem.hac',
#                'size': 185134},
#              { 'handle': None,
#                'name': 'times.fic',
#                'path': 'data/stories/times.fic',
#                'size': 14479},
#              { 'handle': None,
#                'name': 'timetrav.txt',
#                'path': 'data/stories/timetrav.txt',
#                'size': 9375},
#              { 'handle': None,
#                'name': 'tin',
#                'path': 'data/stories/tin',
#                'size': 2795},
#              { 'handle': None,
#                'name': 'tinsoldr.txt',
#                'path': 'data/stories/tinsoldr.txt',
#                'size': 6944},
#              { 'handle': None,
#                'name': 'toilet.s',
#                'path': 'data/stories/toilet.s',
#                'size': 1965},
#              { 'handle': None,
#                'name': 'traitor.txt',
#                'path': 'data/stories/traitor.txt',
#                'size': 1135},
#              { 'handle': None,
#                'name': 'tree.txt',
#                'path': 'data/stories/tree.txt',
#                'size': 3540},
#              { 'handle': None,
#                'name': 'tuc_mees',
#                'path': 'data/stories/tuc_mees',
#                'size': 6372},
#              { 'handle': None,
#                'name': 'uglyduck.txt',
#                'path': 'data/stories/uglyduck.txt',
#                'size': 4683},
#              { 'handle': None,
#                'name': 'unluckwr.txt',
#                'path': 'data/stories/unluckwr.txt',
#                'size': 4128},
#              { 'handle': None,
#                'name': 'vaincrow.txt',
#                'path': 'data/stories/vaincrow.txt',
#                'size': 2645},
#              { 'handle': None,
#                'name': 'vainsong.txt',
#                'path': 'data/stories/vainsong.txt',
#                'size': 10925},
#              { 'handle': None,
#                'name': 'valen',
#                'path': 'data/stories/valen',
#                'size': 14686},
#              { 'handle': None,
#                'name': 'vampword.txt',
#                'path': 'data/stories/vampword.txt',
#                'size': 1108},
#              { 'handle': None,
#                'name': 'vday.hum',
#                'path': 'data/stories/vday.hum',
#                'size': 11086},
#              { 'handle': None,
#                'name': 'veiledl.txt',
#                'path': 'data/stories/veiledl.txt',
#                'size': 24615},
#              { 'handle': None,
#                'name': 'vgilante.txt',
#                'path': 'data/stories/vgilante.txt',
#                'size': 671603},
#              { 'handle': None,
#                'name': 'wall.art',
#                'path': 'data/stories/wall.art',
#                'size': 1924},
#              { 'handle': None,
#                'name': 'wanderer.fun',
#                'path': 'data/stories/wanderer.fun',
#                'size': 1757},
#              { 'handle': None,
#                'name': 'weaver.txt',
#                'path': 'data/stories/weaver.txt',
#                'size': 4411},
#              { 'handle': None,
#                'name': 'weeprncs.txt',
#                'path': 'data/stories/weeprncs.txt',
#                'size': 5363},
#              { 'handle': None,
#                'name': 'whgdsreg.reg',
#                'path': 'data/stories/whgdsreg.reg',
#                'size': 7570},
#              { 'handle': None,
#                'name': 'wisteria.txt',
#                'path': 'data/stories/wisteria.txt',
#                'size': 64414},
#              { 'handle': None,
#                'name': 'withdraw.cyb',
#                'path': 'data/stories/withdraw.cyb',
#                'size': 13668},
#              { 'handle': None,
#                'name': 'wlgirl.txt',
#                'path': 'data/stories/wlgirl.txt',
#                'size': 8127},
#              { 'handle': None,
#                'name': 'wolf7kid.txt',
#                'path': 'data/stories/wolf7kid.txt',
#                'size': 5786},
#              { 'handle': None,
#                'name': 'wolfcran.txt',
#                'path': 'data/stories/wolfcran.txt',
#                'size': 2366},
#              { 'handle': None,
#                'name': 'wolflamb.txt',
#                'path': 'data/stories/wolflamb.txt',
#                'size': 1767},
#              { 'handle': None,
#                'name': 'wombat.und',
#                'path': 'data/stories/wombat.und',
#                'size': 2320},
#              { 'handle': None,
#                'name': 'write',
#                'path': 'data/stories/write',
#                'size': 2695},
#              { 'handle': None,
#                'name': 'wrt',
#                'path': 'data/stories/wrt',
#                'size': 19047},
#              { 'handle': None,
#                'name': 'yukon.txt',
#                'path': 'data/stories/yukon.txt',
#                'size': 76563},
#              { 'handle': None,
#                'name': 'zombies.txt',
#                'path': 'data/stories/zombies.txt',
#                'size': 61632}],
#   'total_size': 12764422}
# { 'files': [ { 'handle': None,
#                'name': 'cbt_valid.txt',
#                'path': 'data/CBTest/data/cbt_valid.txt',
#                'size': 1182697},
#              { 'handle': None,
#                'name': 'cbtest_CN_valid_2000ex.txt',
#                'path': 'data/CBTest/data/cbtest_CN_valid_2000ex.txt',
#                'size': 4641257},
#              { 'handle': None,
#                'name': 'cbtest_NE_valid_2000ex.txt',
#                'path': 'data/CBTest/data/cbtest_NE_valid_2000ex.txt',
#                'size': 4328316},
#              { 'handle': None,
#                'name': 'cbtest_P_valid_2000ex.txt',
#                'path': 'data/CBTest/data/cbtest_P_valid_2000ex.txt',
#                'size': 4680981},
#              { 'handle': None,
#                'name': 'cbtest_V_valid_2000ex.txt',
#                'path': 'data/CBTest/data/cbtest_V_valid_2000ex.txt',
#                'size': 4460425}],
#   'total_size': 19293676}
# { 'files': [ { 'handle': None,
#                'name': '.cbt_test.txt.swp',
#                'path': 'data/CBTest/data/.cbt_test.txt.swp',
#                'size': 1024},
#              { 'handle': None,
#                'name': 'cbt_test.txt',
#                'path': 'data/CBTest/data/cbt_test.txt',
#                'size': 1528744},
#              { 'handle': None,
#                'name': 'cbtest_CN_test_2500ex.txt',
#                'path': 'data/CBTest/data/cbtest_CN_test_2500ex.txt',
#                'size': 6018376},
#              { 'handle': None,
#                'name': 'cbtest_NE_test_2500ex.txt',
#                'path': 'data/CBTest/data/cbtest_NE_test_2500ex.txt',
#                'size': 5587722},
#              { 'handle': None,
#                'name': 'cbtest_P_test_2500ex.txt',
#                'path': 'data/CBTest/data/cbtest_P_test_2500ex.txt',
#                'size': 5958048},
#              { 'handle': None,
#                'name': 'cbtest_V_test_2500ex.txt',
#                'path': 'data/CBTest/data/cbtest_V_test_2500ex.txt',
#                'size': 5686625}],
#   'total_size': 24780539}
